# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,RANSACRegressor
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
import seaborn 
import matplotlib.pyplot as plt

# %%
# Replace with the actual path to your downloaded dataset
data = pd.read_csv("instagram_reach.csv")

# %%
data
# Out:
#     Unnamed: 0  S.No              USERNAME  \
# 0            0     1         mikequindazzi
# 1            1     2       drgorillapaints
# 2            2     3    aitrading_official
# 3            3     4  opensourcedworkplace
# 4            4     5           crea.vision
# ..         ...   ...                   ...
# 95           8    19        michaelgarza__
# 96           9    21           dvlp_search
# 97          10    22            ecom.space
# 98          11    24        lb3enterprises
# 99          12    25          palmariusdev
#
#                                               Caption  Followers  \
# 0   Who are #DataScientist and what do they do? >>...       1600
# 1   We all know where it’s going. We just have to ...        880
# 2   Alexander Barinov: 4 years as CFO in multinati...        255
# 3                                                sfad        340
# 4   Ever missed a call while your phone was chargi...        304
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         100 non-null    int64
#  1   S.No               100 non-null    int64
#  2   USERNAME           100 non-null    object
#  3   Caption            94 non-null     object
#  4   Followers          100 non-null    int64
#  5   Hashtags           100 non-null    object
#  6   Time since posted  100 non-null    object
#  7   Likes              100 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'S.No', 'USERNAME', 'Caption', 'Followers', 'Hashtags',
#        'Time since posted', 'Likes'],
#       dtype='object')

# %%
# pairplot with hue
seaborn.pairplot(data)
plt.show()

# %%
# Data cleaning, feature engineering, and text preprocessing steps (adjust as needed)

# Split data into features (X) and targets (y)
X = data.drop(['S.No','Unnamed: 0', "Likes", "Time since posted"], axis=1)

# %%
X
# Out:
#                 USERNAME                                            Caption  \
# 0          mikequindazzi  Who are #DataScientist and what do they do? >>...
# 1        drgorillapaints  We all know where it’s going. We just have to ...
# 2     aitrading_official  Alexander Barinov: 4 years as CFO in multinati...
# 3   opensourcedworkplace                                               sfad
# 4            crea.vision  Ever missed a call while your phone was chargi...
# ..                   ...                                                ...
# 95        michaelgarza__  328 S. Wetherly Drive, Beverly Hills, CA 90212...
# 96           dvlp_search  Credit @tristankappel To find more dvlp follow...
# 97            ecom.space  We are coming up with the Best 21 Books that w...
# 98        lb3enterprises  We’re only paid to move dirt once. It’s not ju...
# 99          palmariusdev                    Obtén tu tienda en línea ahora.
#
# ...

# %%
y_likes = data["Likes"]
y_time_since_posted = data["Time since posted"]

# %%
y_likes
# Out:
# 0     139
# 1      23
# 2      25
# 3      49
# 4      30
#      ...
# 95     31
# 96     42
# 97     10
# 98    222
# 99    109
# Name: Likes, Length: 100, dtype: int64

# %%
y_time_since_posted
# Out:
# 0     11 hours
# 1      2 hours
# 2      2 hours
# 3      3 hours
# 4      3 hours
#         ...
# 95     3 hours
# 96     3 hours
# 97     3 hours
# 98     3 hours
# 99     3 hours
# Name: Time since posted, Length: 100, dtype: object

# %%
# Split data into training and testing sets
X_train, X_test, y_likes_train, y_likes_test, y_time_since_posted_train, y_time_since_posted_test = train_test_split(
    X, y_likes, y_time_since_posted, test_size=0.2, random_state=42)

# %%
# Create and train the model
model_likes = LinearRegression()

# %%
model_likes.fit(X_train, y_likes_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16940\2082084696.py in ?()
# ----> 1 model_likes.fit(X_train, y_likes_train)
#
# ~\anaconda3\envs\condaEnv3JNB\lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     645         n_jobs_ = self.n_jobs
#     646
#     647         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     648
# --> 649         X, y = self._validate_data(
#     650             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     651         )
#     652
#
# ~\anaconda3\envs\condaEnv3JNB\lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, **check_params)
#     550                 if "estimator" not in check_y_params:
#     551                     check_y_params = {**default_check_params, **check_y_params}
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16940\1232248910.py in ?()
#       1 # Create and train the model
#       2 model_likes = LinearRegression()  # Replace with your chosen model
# ----> 3 model_likes.fit(X_train, y_likes_train)
#
# ~\anaconda3\envs\condaEnv3JNB\lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     645         n_jobs_ = self.n_jobs
#     646
#     647         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     648
# --> 649         X, y = self._validate_data(
#     650             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     651         )
#     652
#
# ~\anaconda3\envs\condaEnv3JNB\lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, **check_params)
#     550                 if "estimator" not in check_y_params:
# ...

# %%
# Make predictions on the testing set
y_likes_pred = model_likes.predict(X_test)

# Evaluate model performance
mse_likes = mean_squared_error(y_likes_test, y_likes_pred)
print("Mean Squared Error (Likes prediction):", mse_likes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16940\2959286188.py in ?()
#       1 # Create and train the model
#       2 model_likes = LinearRegression()  # Replace with your chosen model
# ----> 3 model_likes.fit(X_train, y_likes_train)
#       4
#       5 # Make predictions on the testing set
#       6 y_likes_pred = model_likes.predict(X_test)
#
# ~\anaconda3\envs\condaEnv3JNB\lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     645         n_jobs_ = self.n_jobs
#     646
#     647         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     648
# --> 649         X, y = self._validate_data(
#     650             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     651         )
#     652
#
# ...

# %%
 model_time = RandomForestRegressor()

# %%
# Train the model
model_time.fit(X_train, y_time_since_posted_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16940\1424246665.py in ?()
#       1 # Train the model
# ----> 2 model_time.fit(X_train, y_time_since_posted_train)
#
# ~\anaconda3\envs\condaEnv3JNB\lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     342
#     343         # Validate or convert input data
#     344         if issparse(y):
#     345             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 346         X, y = self._validate_data(
#     347             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     348         )
#     349         if sample_weight is not None:
#
# ~\anaconda3\envs\condaEnv3JNB\lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, **check_params)
#     550                 if "estimator" not in check_y_params:
# ...

# %%
# Evaluate model performance
evaluation_score = evaluation_metric(y_time_since_posted_test, y_time_since_posted_pred)
print("Evaluation Score (Time Since posted prediction):", evaluation_score)
